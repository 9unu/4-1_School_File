# %% [markdown]
# 180명
#
# 중간 20 만점
#
# 기말 60 만점

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\USER\Desktop\4학년 1학기\(월,수) 응용데이터분석\강의 자료\ADA_03_dataset_score.csv")

# %% [markdown]
# # 데이터 확인

# %%
len(data)
# Out:
# 179

# %%
data.describe()
# Out:
#           Midterm       Final
# count  178.000000  179.000000
# mean    14.078652   30.156425
# std      5.070630   18.975978
# min      0.000000    0.000000
# 25%     10.250000   13.000000
# 50%     15.000000   33.000000
# 75%     19.000000   48.000000
# max     20.000000   64.000000

# %% [markdown]
# 문제점 : 기말 만점이 60점인데, 넘는 사람이 있음

# %%
data.isnull().sum()
# Out:
# Midterm    1
# Final      0
# dtype: int64

# %%
data.head()
# Out:
#    Midterm  Final
# 0      7.0     40
# 1     10.0     11
# 2     19.0     54
# 3     11.0     37
# 4     15.0     54

# %%
data[data['Final']>60]
# Out:
#      Midterm  Final
# 176     19.0     64

# %% [markdown]
# anormaly 찾음

# %%
data=data.drop(176)

# %% [markdown]
# ## 데이터 분포 확인

# %%
plt.hist(data['Midterm'])
plt.title("Midterm hist")
plt.show()
plt.hist(data['Final'])
plt.title("Final hist")
plt.show()

# %% [markdown]
# ## 이상치 확인

# %%
plt.scatter(data['Midterm'], data['Final'])
plt.xlabel('midterm')
plt.ylabel('final')
plt.title('Relationship between midterm score and final score')
plt.show()

# %%
import seaborn as sns

data.boxplot()
 
for i, d in enumerate(data):
    y = data[d]
    x = np.random.normal(i + 1, 0.02, len(y))
    plt.scatter(x, y)
plt.title("midterm and Final boxplot")    
plt.show()
