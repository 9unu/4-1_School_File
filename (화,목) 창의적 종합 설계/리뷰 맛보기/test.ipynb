# %%
import pandas as pd
import json
import os

# %%
data=pd.read_json('review.json', encoding = 'utf-8-sig')

# %%
data.columns
# Out:
# Index(['id', 'buyOption', 'content', 'aidaCreateTime', 'aidaModifyTime',
#        'esModifyTime', 'imageCount', 'imageYn', 'images', 'mallId',
#        'mallProductId', 'mallReviewId', 'mallSeq', 'matchNvMid', 'modifyDate',
#        'nvMid', 'pageUrl', 'qualityScore', 'rankScore', 'registerDate',
#        'starScore', 'title', 'topicCount', 'topicYn', 'topics', 'userId',
#        'videoCount', 'videoYn', 'videos', 'mallName', 'mallLogoUrl'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                 0
# buyOption         42
# content            0
# aidaCreateTime     0
# aidaModifyTime     0
# esModifyTime       0
# imageCount         0
# imageYn            0
# images             0
# mallId             0
# mallProductId      0
# mallReviewId       0
# mallSeq            0
# matchNvMid         0
# modifyDate         0
# nvMid              0
# pageUrl            1
# qualityScore       0
# rankScore          0
# registerDate       0
# starScore          0
# title              0
# topicCount         0
# topicYn            0
# topics             0
# userId             0
# videoCount         0
# videoYn            0
# videos             0
# mallName           0
# mallLogoUrl        0
# dtype: int64

# %%
n = len(data.columns)
i = 0
while i < n:
    print(data.iloc[:, i:i+1].head())
    i += 1
    print("*"* 30)
# Out:
#                                     id
# 0  4440892545-ncp_1o6cqz_01-7832366877
# 1  4435156948-ncp_1nrg38_01-7819270784
# 2             4425061139-116863-983676
# 3       4408099756-dareum74-7861344061
# 4        2427679733-auction-C883900059
# ******************************
#    buyOption
# 0  색상선택: 화이트
# 1  색상 선택: 블랙
# 2       None
# 3    색상: 화이트
# 4       None
# ******************************
#                                              content
# 0                                    음질 괜찮고 디자인 예쁩니다
# 1                        좋아요 근데 페어링이랑 전원키기버튼이같아서불편해여
# 2                     하얀색쓰다가 검은색으로 갈아탔어요~ 마음에 듭니다 ㅎㅎ
# 3                                    정말 잘 사용하고 있습니다.
# 4  <em>좋아요</em> <em>이 제품은 가격 대비 성능이  쓸 수록 훌륭합니다</...
# ******************************
#         aidaCreateTime
# 0  2024-03-13 15:35:10
# 1  2024-03-02 15:35:25
# 2  2024-02-14 15:31:13
# 3  2024-01-16 15:31:52
# 4  2023-12-30 15:00:43
# ******************************
#         aidaModifyTime
# 0  2024-03-14 03:55:05
# ...
